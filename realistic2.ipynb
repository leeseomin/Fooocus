# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/leeseomin/Fooocus.git
# %cd /content/Fooocus

# !python entry_with_update.py --share

#!python entry_with_update.py --preset anime --share


# !python entry_with_update.py --preset realistic2 --share
# Out:
# Collecting pygit2==1.12.2
#   Downloading pygit2-1.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pygit2==1.12.2) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.9.1->pygit2==1.12.2) (2.21)
# Installing collected packages: pygit2
# Successfully installed pygit2-1.12.2
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 5192, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 5192 (delta 35), reused 40 (delta 25), pack-reused 5137
# Receiving objects: 100% (5192/5192), 24.97 MiB | 22.57 MiB/s, done.
# Resolving deltas: 100% (3178/3178), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--preset', 'realistic2', '--share']
# Loaded preset: /content/Fooocus/presets/realistic2.json
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.856
# Installing requirements
# Downloading: "https://civitai.com/api/download/models/294470" to /content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors
#
# 100% 6.46G/6.46G [05:44<00:00, 20.2MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors" to /content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors
#
# 100% 222M/222M [00:00<00:00, 251MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 1.27MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 7.16MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xl-to-v1_interposer-v3.1.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v3.1.safetensors
#
# 100% 6.25M/6.25M [00:00<00:00, 113MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 272MB/s]
# Total VRAM 15102 MB, total RAM 12979 MB
# Running on local URL:  http://127.0.0.1:7865
# 2024-01-12 10:10:03.131838: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-12 10:10:03.131948: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-12 10:10:03.244580: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Running on public URL: https://7e0767cce232cd0226.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# 2024-01-12 10:10:04.899603: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Set vram state to: NORMAL_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_g.transformer.text_model.embeddings.position_ids', 'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# Base model loaded: /content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors
# Request to load LoRAs [['SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors', 0.25], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors] for UNet [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors] with 788 keys at weight 0.25.
# Loaded LoRA [/content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors] for CLIP [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors] with 264 keys at weight 0.25.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.17 seconds
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://7e0767cce232cd0226.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 3.0
# [Parameters] Seed = 2949272807486582516
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] sexy russian 1girl in cafe., headshot, hair cover ear, striking eyes, modern outfit, pastel background, confident and graceful posture, see through look.(Dreamscape:1.5). (ethereal:1.5),(Rembrandt Lighting),(rich rosy skin) (Dim lighting) (cinematic lighting:1.2).(hazy filter. film grain:1.2) <lora:add-detail-xl:1.5>, Arri Alexa film camera, 75mm lens, complex composition, highly detailed, atmosphere, stunning, beautiful, ambient, full color, cinematic, intricate, elegant, luxurious, light, iconic, fine detail, rich deep colors
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] sexy russian 1girl in cafe., headshot, hair cover ear, striking eyes, modern outfit, pastel background, confident and graceful posture, see through look.(Dreamscape:1.5). (ethereal:1.5),(Rembrandt Lighting),(rich rosy skin) (Dim lighting) (cinematic lighting:1.2).(hazy filter. film grain:1.2) <lora:add-detail-xl:1.5>, Arri Alexa film camera, 75mm lens, sharp focus, very coherent, elegant, intricate, highly detailed, rich deep colors, positive aesthetic, glowing atmosphere, full perfect, cinematic, beautiful dynamic dramatic surreal, holy sacred
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] sexy russian 1girl in cafe., headshot, hair cover ear, striking eyes, modern outfit, pastel background, confident and graceful posture, see through look.(Dreamscape:1.5). (ethereal:1.5),(Rembrandt Lighting),(rich rosy skin) (Dim lighting) (cinematic lighting:1.2).(hazy filter. film grain:1.2) <lora:add-detail-xl:1.5>, Arri Alexa film camera, 75mm lens, precise sharp focus, ambient light, dynamic dramatic cinematic colors, elegant, intricate, very inspirational, stunning, highly detailed, creative, original, deep color, rational, romantic
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.17 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1024, 1024)
# Preparation time: 5.89 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.18 seconds
# 100% 60/60 [00:59<00:00,  1.00it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.32 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-12/log.html
# Generating and saving time: 65.35 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.11 seconds
# 100% 60/60 [01:00<00:00,  1.00s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-12/log.html
# Generating and saving time: 65.19 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.14 seconds
#  35% 21/60 [00:21<00:39,  1.01s/it]
