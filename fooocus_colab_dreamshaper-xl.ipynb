# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/leeseomin/Fooocus.git
# %cd /content/Fooocus

# !python entry_with_update.py --share

#!python entry_with_update.py --preset anime --share


# !python entry_with_update.py --preset dreamshaper-xl --share
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 36.0 MB/s eta 0:00:00
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 4477, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 4477 (delta 94), reused 133 (delta 82), pack-reused 4328
# Receiving objects: 100% (4477/4477), 24.28 MiB | 34.87 MiB/s, done.
# Resolving deltas: 100% (2720/2720), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--preset', 'realistic', '--share']
# Loaded preset: /content/Fooocus/presets/realistic.json
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.824
# Installing requirements
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v10.safetensors" to /content/Fooocus/models/checkpoints/realisticStockPhoto_v10.safetensors
#
# 100% 6.46G/6.46G [00:55<00:00, 125MB/s]
# ...
